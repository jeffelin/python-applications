# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %%
unemployment_df = pd.read_csv(r'\python-applications\data_analysis\unemployment\unemployment_data\unemployment\output.csv')

# %%
unemployment_df.head()
# Out:
#    Year     Month        State         County  Rate
# 0  2015  February  Mississippi  Newton County   6.1
# 1  2015  February  Mississippi  Panola County   9.4
# 2  2015  February  Mississippi  Monroe County   7.9
# 3  2015  February  Mississippi   Hinds County   6.1
# 4  2015  February  Mississippi  Kemper County  10.6

# %%
average = np.average(unemployment_df['Rate'])
average
# Out:
# 6.175009711500675

# %%
unemployment_df['Year']
# Out:
# 0         2015
# 1         2015
# 2         2015
# 3         2015
# 4         2015
#           ...
# 885543    2009
# 885544    2009
# 885545    2009
# 885546    2009
# 885547    2009
# Name: Year, Length: 885548, dtype: int64

# %%
# Scatter plot with day against tip
plt.scatter(unemployment_df['Year'], unemployment_df['Rate'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Year')
plt.ylabel('Rate')

plt.colorbar()
plt.show()

# %%
# Scatter plot with day against tip
plt.plot(unemployment_df['Year'])
plt.plot(unemployment_df['Rate'])

# Adding Title to the Plot
plt.title("Scatter Plot")

# Setting the X and Y labels
# Setting the X and Y labels
plt.xlabel('Year')
plt.ylabel('Rate')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Bar chart with day against tip
plt.bar(unemployment_df['Year'], unemployment_df['Rate'])

plt.title("Bar Chart")

# Setting the X and Y labels
plt.xlabel('Year')
plt.ylabel('Rate')

# Adding the legends
plt.show()

# %%
# histogram of total_bills
plt.hist(unemployment_df['Rate'])

plt.title("Histogram")

# Adding the legends
plt.show()

# %%
# draw lineplot
sns.lineplot(x="Rate", y="Year", data=unemployment_df)

# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')

plt.show()

# %%
sns.scatterplot(x="Rate", y="Year", data=unemployment_df)
plt.show()

# %%
sns.lineplot(data=unemployment_df.drop(['Rate'], axis=1))
plt.show()
